# %%
import pandas as pd

# %%
data = pd.read_csv('/content/drive/MyDrive/Final Project /Datasets/scripts/processed_scripts.csv')

# %%
df = pd.read_csv('/content/location_extraction_results.csv')

# %%
from transformers import pipeline

# Initialize a named entity recognition pipeline
# The model used here is pre-trained for NER tasks
ner = pipeline("ner", model="dbmdz/bert-large-cased-finetuned-conll03-english", grouped_entities=True)

# Function to extract locations
def extract_locations(script_text):
    """
    Extracts location-related entities (LOC, GPE, etc.) from the given text using the NER pipeline.
    """
    if pd.isnull(script_text) or script_text.strip() == "":
        return []  # Return an empty list if the text is null or empty

    # Use the NER pipeline to process the text
    entities = ner(script_text)

    # Extract entities tagged as 'LOC' or 'GPE' (Geopolitical Entity)
    locations = [entity['word'] for entity in entities if entity['entity_group'] in ['LOC', 'GPE']]

    return locations

# Define batch processing function
def process_in_batches(data, batch_size, output_file):
    """
    Processes the dataset in batches and saves results incrementally to avoid memory issues.
    """
    total_rows = len(data)
    for start_idx in range(0, total_rows, batch_size):
        end_idx = min(start_idx + batch_size, total_rows)
        batch = data.iloc[start_idx:end_idx]

        # Apply location extraction to the current batch
        batch['Extracted Locations'] = batch['Script/Subtitle Text'].apply(extract_locations)

        # Append the results to the output file
        if start_idx == 0:  # If it's the first batch, write the header
            batch.to_csv(output_file, mode='w', index=False)
        else:  # Append without writing the header
            batch.to_csv(output_file, mode='a', header=False, index=False)

        print(f"Processed rows {start_idx} to {end_idx} out of {total_rows}")

# Set batch size and output file
batch_size = 500  # Adjust batch size based on your memory and performance needs
output_file = "location_extraction_results.csv"

# Process dataset in batches
process_in_batches(data, batch_size, output_file)

print(f"Batch processing completed! Results saved to {output_file}.")

# %%
df.shape
# Out:
# (18500, 5)

# %%
df
# Out:
#        Unnamed: 0                    Movie Name  \
# 0               0                 My Sassy Girl
# 1               1             Friday After Next
# 2               2                       Zillion
# 3               3                          2002
# 4               4                       Area 51
# ...           ...                           ...
# 18495       18495               We Dive at Dawn
# 18496       18496                 Yellow Canary
# 18497       18497             Young and Willing
# 18498       18498                 The Abandoned
# 18499       18499  The Adventures of Mark Twain
#
#                                     Script/Subtitle Text  \
# 0      - This is the storyof the first and last timeI...
# 1      'Twas the night before Christmas,and all throu...
# 2      1If you're stupid, thenyou can easily hide tha...
# 3      This is roof.Where did she fall from?Sir, she ...
# 4      1Reid, Ben, and Darrin and I,we've been friend...
# ...                                                  ...
# 18495  - Nearly at the boom, sir.- Yes, we'll be in b...
# 18496  CHURCH BELLS RINGCLOCK STRIKES NINEI'm afraid ...
# 18497  Well, what do you think?Is she woman or is she...
# 18498  [INSTRUMENTAL MUSIC][INSTRUMENTAL MUSIC][SIREN...
# 18499  It all started one day......after Tom heard ab...
#
#                                         Processed Script  \
# 0      ['Ġthis', 'Ġis', 'Ġthe', 'Ġstory', 'Ġthe', 'Ġf...
# 1      ['tw', 'Ġthe', 'Ġnight', 'Ġbefore', 'Ġchrist',...
# 2      ['Ġyou', 'Ġstupid', 'Ġthen', 'Ġcan', 'Ġeasily'...
# 3      ['Ġis', 'Ġroof', 'Ġdid', 'Ġshe', 'Ġfall', 'Ġfr...
# 4      ['id', 'Ġben', 'Ġand', 'Ġd', 'arr', 'Ġand', 'Ġ...
# ...                                                  ...
# 18495  ['Ġnearly', 'Ġat', 'Ġthe', 'Ġboom', 'Ġsir', 'Ġ...
# 18496  ['church', 'Ġbells', 'Ġring', 'clock', 'Ġstrik...
# 18497  ['well', 'Ġwhat', 'Ġdo', 'Ġyou', 'Ġthink', 'Ġs...
# 18498  ['Ġmostly', 'Ġcloudy', 'Ġscattered', 'Ġshowers...
# 18499  ['Ġall', 'Ġstarted', 'Ġone', 'Ġday', 'Ġtom', '...
#
#                                      Extracted Locations
# 0                             ['French Lick', 'Indiana']
# 1                                                     []
# 2                            ['Meise', 'Meise', 'China']
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 18495                                                 []
# 18496  ['British Museum', 'Circle', 'WA', '##ockspur'...
# 18497                  ['Empire State Building', 'York']
# 18498                                             ['RA']
# 18499      ['Saint Louis', 'Saint Louis', 'Saint Louis']
#
# [18500 rows x 5 columns]

# %%
df1 = pd.read_csv('/content/location_extraction_results_last_4100.csv')

# %%
columns_to_drop = ["Unnamed: 0"]
df1 = df1.drop(columns=columns_to_drop, errors="ignore")
df1
# Out:
#                  Movie Name  \
# 0                    Alaska
# 1          And Now Tomorrow
# 2      Arsenic and Old Lace
# 3             Atlantic City
# 4         Aventure malgache
# ...                     ...
# 4144             Yellow Sky
# 4145   You Gotta Stay Happy
# 4146                   Mama
# 4147  A Haunting We Will Go
# 4148              Abandoned
#
#                                    Script/Subtitle Text  \
# 0     1Quincy Air Serviceto Super Cub 909-Tango.Do y...
# 1     That means you can't doanything for me, doesn'...
# 2     ARSENIC AND OLD LACEWritten by\r\n\r\n        ...
# 3     Look, it's Ganesh!It's a sign from heaven.Good...
# 4     The entire world has heard aboutthe dramatic e...
# ...                                                 ...
# 4144  [Thunderclap]Hey, look at that!Look. Right thr...
# 4145  We've been waitingsome time.Hey! Hey, pop!Excu...
# 4146  Hearing-transcriptedEnglish subtitle by watdde...
# 4147  Well, gentlemen, we trust you|spent a comforta...
# 4148  (EERIE MUSIC PLAYING)(MUSIC CONTINUES)(HULL CR...
#
#                                        Processed Script  \
# 0     ['quin', 'cy', 'Ġair', 'Ġservic', 'eto', 'Ġsup...
# 1     ['Ġmeans', 'Ġyou', 'Ġcant', 'Ġdo', 'anything',...
# 2     ['ars', 'enic', 'Ġand', 'Ġold', 'Ġlac', 'ew', ...
# 3     ['look', 'Ġits', 'Ġg', 'esh', 'Ġa', 'Ġsign', '...
# 4     ['Ġentire', 'Ġworld', 'Ġhas', 'Ġheard', 'Ġabou...
# ...                                                 ...
# 4144  ['hey', 'Ġlook', 'Ġat', 'Ġthat', 'look', 'Ġrig...
# 4145  ['Ġbeen', 'Ġwait', 'ings', 'ome', 'Ġtime', 'he...
# 4146  ['aring', 'trans', 'cript', 'ed', 'english', '...
# 4147  ['well', 'Ġgentlemen', 'Ġwe', 'Ġtrust', 'Ġyou'...
# 4148  ['wh', 'ats', 'Ġthat', 'Ġjohn', 'Ġwhats', 'Ġha...
#
#                                     Extracted Locations
# 0                         ['Denali', 'Quincy', 'Earth']
# 1     ['Vienna', 'London', 'Johns Hopkins', 'Rochest...
# 2      ['Brooklyn', 'New York', 'Brooklyn', 'Brooklyn']
# 3     ['Atlantic City', 'Atlantic City', 'Utah', 'Co...
# 4     ['Empire', '##lwyn Studios', 'England', 'Great...
# ...                                                 ...
# 4144                                                 []
# 4145                                                 []
# 4146                                                 []
# 4147  ['Florida', 'Florida', 'Florida', 'Florida', '...
# 4148                                                 []
#
# [4149 rows x 4 columns]

# %%
df2 = pd.read_csv('/content/location_extraction_results.csv')

# %%
columns_to_drop = ["Unnamed: 0"]
df2 = df2.drop(columns=columns_to_drop, errors="ignore")
df2
# Out:
#                          Movie Name  \
# 0                     My Sassy Girl
# 1                 Friday After Next
# 2                           Zillion
# 3                              2002
# 4                           Area 51
# ...                             ...
# 18495               We Dive at Dawn
# 18496                 Yellow Canary
# 18497             Young and Willing
# 18498                 The Abandoned
# 18499  The Adventures of Mark Twain
#
#                                     Script/Subtitle Text  \
# 0      - This is the storyof the first and last timeI...
# 1      'Twas the night before Christmas,and all throu...
# 2      1If you're stupid, thenyou can easily hide tha...
# 3      This is roof.Where did she fall from?Sir, she ...
# 4      1Reid, Ben, and Darrin and I,we've been friend...
# ...                                                  ...
# 18495  - Nearly at the boom, sir.- Yes, we'll be in b...
# 18496  CHURCH BELLS RINGCLOCK STRIKES NINEI'm afraid ...
# 18497  Well, what do you think?Is she woman or is she...
# 18498  [INSTRUMENTAL MUSIC][INSTRUMENTAL MUSIC][SIREN...
# 18499  It all started one day......after Tom heard ab...
#
#                                         Processed Script  \
# 0      ['Ġthis', 'Ġis', 'Ġthe', 'Ġstory', 'Ġthe', 'Ġf...
# 1      ['tw', 'Ġthe', 'Ġnight', 'Ġbefore', 'Ġchrist',...
# 2      ['Ġyou', 'Ġstupid', 'Ġthen', 'Ġcan', 'Ġeasily'...
# 3      ['Ġis', 'Ġroof', 'Ġdid', 'Ġshe', 'Ġfall', 'Ġfr...
# 4      ['id', 'Ġben', 'Ġand', 'Ġd', 'arr', 'Ġand', 'Ġ...
# ...                                                  ...
# 18495  ['Ġnearly', 'Ġat', 'Ġthe', 'Ġboom', 'Ġsir', 'Ġ...
# 18496  ['church', 'Ġbells', 'Ġring', 'clock', 'Ġstrik...
# 18497  ['well', 'Ġwhat', 'Ġdo', 'Ġyou', 'Ġthink', 'Ġs...
# 18498  ['Ġmostly', 'Ġcloudy', 'Ġscattered', 'Ġshowers...
# 18499  ['Ġall', 'Ġstarted', 'Ġone', 'Ġday', 'Ġtom', '...
#
#                                      Extracted Locations
# 0                             ['French Lick', 'Indiana']
# 1                                                     []
# 2                            ['Meise', 'Meise', 'China']
# 3                                                     []
# 4                                                     []
# ...                                                  ...
# 18495                                                 []
# 18496  ['British Museum', 'Circle', 'WA', '##ockspur'...
# 18497                  ['Empire State Building', 'York']
# 18498                                             ['RA']
# 18499      ['Saint Louis', 'Saint Louis', 'Saint Louis']
#
# [18500 rows x 4 columns]

# %%
df_combined = pd.concat([df1, df2], axis=0, ignore_index=True)

# %%
df_combined
# Out:
#                          Movie Name  \
# 0                            Alaska
# 1                  And Now Tomorrow
# 2              Arsenic and Old Lace
# 3                     Atlantic City
# 4                 Aventure malgache
# ...                             ...
# 22644               We Dive at Dawn
# 22645                 Yellow Canary
# 22646             Young and Willing
# 22647                 The Abandoned
# 22648  The Adventures of Mark Twain
#
#                                     Script/Subtitle Text  \
# 0      1Quincy Air Serviceto Super Cub 909-Tango.Do y...
# 1      That means you can't doanything for me, doesn'...
# 2      ARSENIC AND OLD LACEWritten by\r\n\r\n        ...
# 3      Look, it's Ganesh!It's a sign from heaven.Good...
# 4      The entire world has heard aboutthe dramatic e...
# ...                                                  ...
# 22644  - Nearly at the boom, sir.- Yes, we'll be in b...
# 22645  CHURCH BELLS RINGCLOCK STRIKES NINEI'm afraid ...
# 22646  Well, what do you think?Is she woman or is she...
# 22647  [INSTRUMENTAL MUSIC][INSTRUMENTAL MUSIC][SIREN...
# 22648  It all started one day......after Tom heard ab...
#
#                                         Processed Script  \
# 0      ['quin', 'cy', 'Ġair', 'Ġservic', 'eto', 'Ġsup...
# 1      ['Ġmeans', 'Ġyou', 'Ġcant', 'Ġdo', 'anything',...
# 2      ['ars', 'enic', 'Ġand', 'Ġold', 'Ġlac', 'ew', ...
# 3      ['look', 'Ġits', 'Ġg', 'esh', 'Ġa', 'Ġsign', '...
# 4      ['Ġentire', 'Ġworld', 'Ġhas', 'Ġheard', 'Ġabou...
# ...                                                  ...
# 22644  ['Ġnearly', 'Ġat', 'Ġthe', 'Ġboom', 'Ġsir', 'Ġ...
# 22645  ['church', 'Ġbells', 'Ġring', 'clock', 'Ġstrik...
# 22646  ['well', 'Ġwhat', 'Ġdo', 'Ġyou', 'Ġthink', 'Ġs...
# 22647  ['Ġmostly', 'Ġcloudy', 'Ġscattered', 'Ġshowers...
# 22648  ['Ġall', 'Ġstarted', 'Ġone', 'Ġday', 'Ġtom', '...
#
#                                      Extracted Locations
# 0                          ['Denali', 'Quincy', 'Earth']
# 1      ['Vienna', 'London', 'Johns Hopkins', 'Rochest...
# 2       ['Brooklyn', 'New York', 'Brooklyn', 'Brooklyn']
# 3      ['Atlantic City', 'Atlantic City', 'Utah', 'Co...
# 4      ['Empire', '##lwyn Studios', 'England', 'Great...
# ...                                                  ...
# 22644                                                 []
# 22645  ['British Museum', 'Circle', 'WA', '##ockspur'...
# 22646                  ['Empire State Building', 'York']
# 22647                                             ['RA']
# 22648      ['Saint Louis', 'Saint Louis', 'Saint Louis']
#
# [22649 rows x 4 columns]

# %%
df_combined.to_csv('location_extracted.csv', index=False)
